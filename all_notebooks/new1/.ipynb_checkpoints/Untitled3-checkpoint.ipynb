// %%
import $ivy.`com.github.melrief::purecsv:0.1.1`
import scala.util.Try
import purecsv.unsafe.CSVReader

// %%
import $ivy.`io.circe::circe-core:0.12.3`
import $ivy.`io.circe::circe-generic:0.12.3`
import $ivy.`io.circe::circe-parser:0.12.3`

// %%
import io.circe.generic.auto._, io.circe.syntax._

// %%
import io.circe.generic.auto._
import io.circe.syntax._
import io.circe._

// %%
import io.circe.Decoder.Result

// %%
case class GroupIterator[T, K, V](iter: Iterator[T], split: T => (K, V), reduce: (V, V) => V) extends Iterator[(K, V)] {
  var currentOutputKey: Option[K] = None
  var currentKey: Option[K] = None
  var currentValue: Option[V] = None
  var localValue: Option[V] = None
  val queue = scala.collection.mutable.Queue[(K, V)]()

  def read(): (Option[K], Option[V]) = {
    if (iter.hasNext) {
      val r = iter.next()
      val (key, value) = split(r)

      (Some(key), Some(value))
    } else {
      (None, None)
    }
  }

  override def hasNext: Boolean = {
    if (!iter.hasNext && queue.isEmpty) {
      if (currentOutputKey.isDefined) {
        queue.enqueue((currentOutputKey.get, currentValue.get))
        currentOutputKey = None
        true
      } else {
        false
      }
    } else if (!iter.hasNext && queue.nonEmpty) {
      true
    } else {
      if (currentOutputKey.isEmpty) {
        val (key, value) = read()
        currentKey = key
        currentOutputKey = key
        currentValue = value
      }

      while (currentKey.isDefined && currentOutputKey == currentKey) {
        val (key, value) = read()
        currentKey = key
        localValue = value
        if (value.isDefined && currentOutputKey == currentKey) {
          currentValue = currentValue.map(x => reduce(x, value.get))
        }
      }

      queue.enqueue((currentOutputKey.get, currentValue.get))
      currentOutputKey = currentKey
      currentValue = localValue

      true
    }
  }

  override def next(): (K, V) = {
    queue.dequeue()
  }
}

class UnionIterator[A](iterators : Seq[Iterator[A]]) extends Iterator[A]{
  // scalastyle:off
  var idx = 0
  var currentIterator : Option[Iterator[A]] = iterators.headOption
  // scalastyle:on

  override def hasNext: Boolean = {
    if (currentIterator.isDefined && currentIterator.get.hasNext) {
      true
    } else {
      while (idx < iterators.length && !iterators(idx).hasNext) {
        idx += 1
      }

      if (idx < iterators.length && iterators(idx).hasNext) {
        currentIterator = Some(iterators(idx))
        true
      } else {
        false
      }
    }
  }

  override def next(): A = currentIterator.get.next()
}

// %%
import java.io._
import java.nio.file.{Files, Paths}

import scala.reflect.io
import scala.reflect.io.Directory

/**
  * Utility object for File access.
  */
object FileUtils {

  type FileName = String
  type Dir = String

  def withFile[A](fileName: FileName)(func: PrintWriter => A): Unit = {
    val file = new File(fileName)
    val write = new PrintWriter(file)
    try {
      func(write)
    } finally {
      write.close()
    }
  }

  /**
    * Directory list
    *
    * @param dir dir
    * @return only filenames, i.e. "/tmp/1/2/3" -> "3"
    */
  def list(dir: Dir): List[FileName] = {
    filesInDir(dir).map(_.name).toList
  }

  /**
    * Full directory list
    *
    * @param dir dir
    * @return full path filenames, i.e. "/tmp/1/2/3"
    */
  def fullList(dir: Dir): List[FileName] = {
    list(dir).map(fileName => s"$dir/$fileName")
  }

  def fromFile(filePath: FileName, encoding: String = "iso-8859-1"): Iterator[String] = scala.io.Source.fromFile(filePath, encoding).getLines

  def readFile(filePath: FileName, encoding: String = "iso-8859-1"): String = fromFile(filePath, encoding).mkString("\n")

  def readBinaryFile(fileName: FileName): Array[Byte] = {
    Files.readAllBytes(Paths.get(fileName))
  }

  def filesInDir(dir: Dir, fileNameFilter: (FileName => Boolean) = (x => true)): Array[io.File] = {
    Directory(dir).files.toArray.filter(file => fileNameFilter(file.name)).sortBy(x => x.name)
  }

  // scalastyle:off regex
  def write(fileName: FileName, iterator: Iterator[String]): Unit = {
    withFile(fileName) { output =>
      iterator.foreach(line => output.println(line))
    }
  }

  // scalastyle:on regex

  def write(fileName: FileName, value: String): Unit = {
    write(fileName, Iterator.single(value))
  }

  def write(fileName: FileName, array: Array[Byte]): Unit = {
    import java.io.FileOutputStream
    val fos = new FileOutputStream(fileName)
    fos.write(array)
    fos.close()
  }

  def write(fileName: FileName, stream: InputStream): Unit = {
    Files.copy(stream, new java.io.File(fileName).toPath)
  }

  def copyFile(srcPath: String, destPath: String): Unit = {
    val src = new File(srcPath)
    val dest = new File(destPath)
    new FileOutputStream(dest).getChannel.transferFrom(
      new FileInputStream(src).getChannel, 0, Long.MaxValue)
  }

  def exist(path: String): Boolean = {
    new java.io.File(path).exists
  }

  def delete(fileName: FileName): Boolean = {
    new File(fileName).delete()
  }

  def deleteNonEmptyDir(dir: Dir): Boolean = {
    filesInDir(dir).foreach(x => delete(x.path))
    new Directory(new File(dir)).delete()
  }

  def fileSize(fileName: FileName): Long = {
    new File(fileName).length()
  }

  def appendLine(fileName: FileName, value: String): Unit = {
    val fileWriter = new FileWriter(fileName, true)
    try {
      fileWriter.write(value)
      fileWriter.write("\n")
    } finally {
      fileWriter.close()
    }
  }
}

// %%
  val all: Map[String, Int] = scala.io.Source.fromFile("all").getLines().drop(1).map(_.split(" ").last).toList.zipWithIndex.toMap
  lazy val allSet = all.keysIterator.map(_.split("\\.").head).toSet
  lazy val all_back: Map[Int, String] = scala.io.Source.fromFile("all").getLines().drop(1).map(_.split(" ").last).toList.zipWithIndex.map(x => (x._2, x._1)).toMap
  lazy val loc: Map[String, String] = scala.io.Source.fromFile("copy").getLines().map(_.split(" ").last).map { x =>
    val split = x.split("/")
    (split(1), split(0))
  }.toMap

// %%
  case class MetaData2(id: String, _type: String, city: String, title: String, author: String, year: String, specs: String, grade: String, sciArea: String, univer: String, board: String) {
    lazy val y: Int = Try {
      val res = year.toInt
      assert(res > 1970 && res < 2021)
      res
    }.getOrElse(0)

    def lastName = author.split(" ").head.toUpperCase
    def firstName = author.split(" ").drop(1).mkString(" ").toUpperCase
  }


  object MetaData2 {
    lazy val err: MetaData2 = MetaData2("", "", "", "", "", "", "", "", "", "", "")

    def fromString(value: String): MetaData2 = {
      Try {
        CSVReader[MetaData2].readCSVFromString(value, delimiter = ',').head
      }.getOrElse(err)
    }

    def fromFile(fileName: String): Iterator[MetaData2] = {
      scala.io.Source.fromFile(fileName, "UTF-8").getLines().drop(1).map(fromString)
    }
  }

// %%
lazy val meta2: Map[String, MetaData2] = MetaData2.fromFile("text.csv").filter(x => allSet.contains(x.id)).map(x => (x.id, x)).toMap

// %%
    def getDissMeta(id: Int): MetaData2 = {
      meta2(all_back(id).dropRight(4))
    }

// %%
//val allMeta2 = MetaData2.fromFile("text.csv").map(x => (x.id, x)).toMap

// %%
  def idToRGB(id: Int): String = {
    all_back(id).split("\\.").head
  }

  def getAuthor2(id: Int): String = {
    meta2(idToRGB(id)).lastName
  }

  def RGBToId(id: String): Int = {
    all(s"$id.txt")
  }

// %%
  case class Profile(id: Int, dubs: List[(Int, Int)], others: List[Int], cnt: Map[Int, Int]) {
    lazy val currentLastName = getAuthor2(id)

    //Author -> Int (copy-paste-blocks)
    lazy val otherCnt: Map[String, Int] = cnt.map {
      case (idOther, cnt) => (getAuthor2(idOther), cnt)
    }

    lazy val otherLastNames: Map[Int, String] = others.map(x => (x, getAuthor2(x))).toMap

    def toCheck = {
      otherCnt.toList.filterNot {
        case (other, _) => other == currentLastName
      }.count {
        case (_, a) => a >= 10
      } > 0
    }

    def toCheck1 = {
      otherCnt.toList.filterNot {
        case (other, _) => other == currentLastName
      }.count {
        case (_, a) => a >= 10
      } > 1
    }

    lazy val otherMetaData: Map[Int, MetaData2] = others.map(x => (x, meta2(idToRGB(x)))).toMap


  }

// %%
  val dubsSimple: scala.collection.mutable.Map[(Int, Int), Int] = scala.collection.mutable.Map().withDefaultValue(0)

  GroupIterator[String, String, List[Int]](scala.io.Source.fromFile("dub100.csv").getLines(), line => {
    val split = line.split("\t")

    (split.take(2).mkString("\t"), List(split(2).toInt))
  },
    {
      (a, b) => a ++ b
    }
  ).foreach { case (_, list) =>
    for (p <- list.combinations(2).toList) {
      val f = p.head
      val l = p.last

      dubsSimple((f, l)) = dubsSimple((f, l)) + 1
      dubsSimple((l, f)) = dubsSimple((l, f)) + 1
    }
  }

// %%
  val dubsHash: scala.collection.mutable.Map[Int, scala.collection.mutable.ArrayBuffer[Long]] =
    scala.collection.mutable.Map[Int, scala.collection.mutable.ArrayBuffer[Long]]().withDefaultValue(scala.collection.mutable.ArrayBuffer[Long]())

  scala.io.Source.fromFile("dub100.csv").getLines().foreach { line =>
    val split = line.split("\t")

    val id = split(2).toInt
    val h = split(0).toLong * Int.MaxValue + split(1).toLong

    if (dubsHash.contains(id)) {
      dubsHash(id).append(h)
    } else {
      dubsHash(id) = scala.collection.mutable.ArrayBuffer[Long](h)
    }
  }

// %%
  val dubsHashCyberDiss: scala.collection.mutable.Map[Int, scala.collection.mutable.ArrayBuffer[Long]] =
    scala.collection.mutable.Map[Int, scala.collection.mutable.ArrayBuffer[Long]]().withDefaultValue(scala.collection.mutable.ArrayBuffer[Long]())

  val dubsHashCyber: scala.collection.mutable.Map[Int, scala.collection.mutable.ArrayBuffer[Long]] =
    scala.collection.mutable.Map[Int, scala.collection.mutable.ArrayBuffer[Long]]().withDefaultValue(scala.collection.mutable.ArrayBuffer[Long]())

  scala.io.Source.fromFile("cd.dubs").getLines().foreach { line =>
    val split = line.split("\t")

    val id = split(2).toInt
    val h = split(0).toLong * Int.MaxValue + split(1).toLong

    if (split.size == 6) {
      if (dubsHashCyber.contains(id)) {
        dubsHashCyber(id).append(h)
      } else {
        dubsHashCyber(id) = scala.collection.mutable.ArrayBuffer[Long](h)
      }
    } else {
      if (dubsHashCyberDiss.contains(id)) {
        dubsHashCyberDiss(id).append(h)
      } else {
        dubsHashCyberDiss(id) = scala.collection.mutable.ArrayBuffer[Long](h)
      }

    }

  }

// %%
  //Id => [(Id, Cnt)]
  val dubsGrouped: Map[Int, List[(Int, Int)]] = dubsSimple.toList.groupBy(_._1._1).mapValues(_.map(x => (x._1._2, x._2))).withDefaultValue(Nil)

// %%
  def find1(id: Int) = {
    val main: List[(Int, Int)] = dubsGrouped(id)
    val otherSet = main.map(_._1).toSet
    val other: List[Int] = otherSet.toList.sorted

    val cnt: Map[Int, Int] = main.toMap

    Profile(id, main, other, cnt)
  }


  def yearEligible(mainYear: Int, other: Int): Boolean = {
    mainYear == 0 || other == 0 || mainYear >= other
  }

  def metaToShort(md: MetaData2): String = {
    s"${md.id}/${md.author}[${md.y}]"
  }

  def isBad(id: Int): Boolean = {
    val profile: Profile = find1(id)
    val mainMeta = meta2(idToRGB(id))

    val mainAuthor = profile.currentLastName
    val otherLastNames: Map[Int, String] = profile.otherLastNames

    val otherMeta: Map[Int, MetaData2] = profile.others.map(x => (x, meta2(idToRGB(x)))).toMap

    val full: List[(Int, String, MetaData2, Int)] = profile.others.map { x =>
      (x, otherLastNames(x), otherMeta(x), profile.cnt(x))
    }

    val suspectIds: Set[Int] = full.filter {
      case (_, lName, md, cnt) => cnt >= 150 && lName != mainAuthor && yearEligible(mainMeta.y, md.y)
    }.sortBy(_._4)(Ordering[Int].reverse).map(x => x._1).toSet

    suspectIds.nonEmpty
  }

// %%
  case class SimpleCount(id: String, cnt: Int)

//  case class Report(main: MetaData2, others: List[MetaData2], red: List[CopyItem], yellow: List[CopyItem], gray: List[CopyItem], self: List[SimpleCount], later: List[SimpleCount])

  case class SimpleReport(main: MetaData2, others: List[MetaData2], red: List[CopyItem2], yellow: List[CopyItem2], gray: List[CopyItem2], self: List[SimpleCount], later: List[SimpleCount])

  case class CopyItem2(sourceId: String, destId: String, size: Int, metaData: MetaData2) {}

// %%
val DD = 15

// %%
def genReport(id: Int): SimpleReport = {
    val profile: Profile = find1(id)
    val mainMeta = meta2(idToRGB(id))
    val otherMetaList: List[MetaData2] = profile.others.map(x => meta2(idToRGB(x)))

    val mainAuthor = profile.currentLastName
    val otherLastNames: Map[Int, String] = profile.otherLastNames

    val otherMeta: Map[Int, MetaData2] = profile.others.map(x => (x, meta2(idToRGB(x)))).toMap

    val full: List[(Int, String, MetaData2, Int)] = profile.others.map { x =>
      (x, otherLastNames(x), otherMeta(x), profile.cnt(x))
    }

    val redIds: Set[Int] = full.filter {
      case (_, lName, md, cnt) => cnt >= DD && lName != mainAuthor && yearEligible(mainMeta.y, md.y)
    }.sortBy(_._4)(Ordering[Int].reverse).map(x => x._1).toSet

    val yellowIds: Set[Int] = full.filter {
      case (_, lName, md, cnt) => (cnt >= 6 && cnt < DD) && lName != mainAuthor && yearEligible(mainMeta.y, md.y)
    }.sortBy(_._4)(Ordering[Int].reverse).map(x => x._1).toSet

    val grayIds: Set[Int] = full.filter {
      case (_, lName, md, cnt) => (cnt <= 5) && lName != mainAuthor && yearEligible(mainMeta.y, md.y)
    }.sortBy(_._4)(Ordering[Int].reverse).map(x => x._1).toSet

    val selfIds: Set[Int] = full.filter {
      case (_, lName, _, _) => lName == mainAuthor
    }.sortBy(_._4)(Ordering[Int].reverse).map(x => x._1).toSet

    val laterIds: Set[Int] = full.filter {
      case (_, lName, md, _) => lName != mainAuthor && !yearEligible(mainMeta.y, md.y)
    }.sortBy(_._4)(Ordering[Int].reverse).map(x => x._1).toSet

    val toGen: List[(Int, Int)] = profile.dubs

    def genBySet(ids: Set[Int]): List[CopyItem2] = {
      toGen.filter(p => ids.contains(p._1)).map {
        case (i, cnt) =>
          CopyItem2(mainMeta.id, otherMeta(i).id, cnt, otherMeta(i))
      }
    }

    def genSimpleBySet(ids: Set[Int]): List[SimpleCount] = {
      toGen.filter(p => ids.contains(p._1)).map {
        case (i, list) =>
          SimpleCount(otherMeta(i).id, list)
      }.sortBy(_.cnt)(Ordering[Int].reverse)
    }

    val red = genBySet(redIds)
    val yellow = genBySet(yellowIds)
    val gray = genBySet(grayIds)

    SimpleReport(mainMeta, otherMetaList, red, yellow, gray, genSimpleBySet(selfIds), genSimpleBySet(laterIds))
  }

// %%
  val allReports: List[SimpleReport] = all_back.keysIterator.flatMap(x => Try {
    List(genReport(x))
  }.getOrElse(Nil)).toList

// %%
    def jaccardBySize(fst: String, snd: String, windowSize: Int): Double = {
      val fs = fst.sliding(windowSize, 1).toSet
      val ss = snd.sliding(windowSize, 1).toSet

      val d = (fs ++ ss).size
      if (d == 0) {
        1
      } else {
        (fs intersect ss).size.toDouble / d
      }
    }

    def jaccard(fst: String, snd: String): Double = {
      jaccardBySize(norm(fst), norm(snd), 3)
    }

    def norm(value: String): String = {
      value.filter(_.isLetter).toUpperCase
    }

// %%
  lazy val disBad: Map[(String, Int), List[((String, Int), String)]] = scala.io.Source.fromFile("DISBASE.txt").getLines().toList.map(x => x.replace("\t", "")).map { x =>
    Try {
      val split = x.split("\\|").toList
      val lastName = split(1).toUpperCase
      val year = Try {
        split(0).takeRight(4).toInt
      }.getOrElse(split(27).takeRight(4).toInt)
      ((lastName, year), x)
    }.getOrElse((("", 0), ""))
  }.groupBy(x => x._1).withDefaultValue(Nil)



    def extractWorkNamefromDisbase(value: String): String = {
      (value + " ").split("\\|")(4)
    }

    def extractSpecfromDisbase(value: String): String = {
      (value + " ").split("\\|").last
    }

    def onlyNum(value: String): String = value.filter(_.isDigit)

    def findDisBad(meta: MetaData2): String = {
      disBad((meta.lastName, meta.y)).find { t =>
        (jaccard(extractWorkNamefromDisbase(t._2), meta.title) > 0.8) || (onlyNum(extractSpecfromDisbase(t._2)) == onlyNum(meta.board)
          )}.map(_.toString()).getOrElse("")
    }

// %%
  def extraGraph(id: String, red: List[CopyItem2]) = {
    val main: Set[Long] = dubsHash(RGBToId(id)).toSet
    val map: Map[String, Set[Long]] = red.map(x => (x.destId, dubsHash(RGBToId(x.destId)).toSet)).toMap

    val fold = (1 to map.size).foldLeft[(Set[Long], Set[String], List[(String, Int)])]((main, Set[String](), Nil)) {
      case ((set, used, acc), _) =>

        val max: (String, Set[Long]) = map.filterKeys(k => !used.contains(k)).maxBy(_._2.intersect(set).size)

        (set -- max._2, used + max._1, acc :+ (max._1, set.intersect(max._2).size))
    }

    fold._3
  }

// %%
  lazy val falseData: Map[String, String] = scala.io.Source.fromFile("falsedat.txt", "UTF-8").getLines().map { line =>
    val split = line.split("//")
    val id = split.head.trim
    val value = split.drop(1).mkString("//")
    (id, value)
  }.toMap.withDefaultValue("")

// %%
lazy  val cyberMeta: Map[String, Int] = scala.io.Source.fromFile("down/meta.c").getLines().map { line =>
    val split = line.split("\t")
    (split.last, split.head.toInt)
  }.toMap

lazy  val cyberMetaRev: Map[Int, String] = cyberMeta.toList.map(x => (x._2, x._1)).toMap

// %%
lazy  val cyberMeta2: Map[String, (String, Int)] = scala.io.Source.fromFile("down/total", "UTF-8").getLines().filter { line =>
    val split = line.split("\t")
    cyberMeta.contains(s"${split.head.split("/").last}.txt")
  }.map { line =>
    val split = line.split("\t")
    (s"${split.head.split("/").last}.txt", (split(1), split(2).toInt))
  }.toMap.withDefaultValue(("", 2048))

// %%
  def getCyberMeta(id :Int): (String, Int) = {
    cyberMeta2(cyberMetaRev(id))
  }

// %%
  val cyberDubs: scala.collection.mutable.Map[(Int, Int), Int] = scala.collection.mutable.Map().withDefaultValue(0)

  val iter1 = GroupIterator[String, String, List[String]](scala.io.Source.fromFile("cd.dubs").getLines(), line => {
    val split = line.split("\t")

    (split.take(2).mkString("\t"), List(line))
  },
    {
      (a, b) => a ++ b
    }
  ).foreach { case (_, list: List[String]) =>

    val diff: List[(Int, Boolean)] = list.map { line =>
      val split = line.split("\t")
      val id = split(2).toInt
      (id, split.size == 6)
    }

    val diss = diff.filter(!_._2).map(_._1)
    val cyber = diff.filter(_._2).map(_._1)

    for {
      d <- diss
      c <- cyber
    } {
      cyberDubs((d, c)) = cyberDubs((d, c)) + 1
    }
  }

// %%
// cyberDubs.count { case (_, value) => value >= 5 }

// %%
  val cyberPairs: Map[Int, List[Int]] = cyberDubs.filter { case (_, value) => value >= DD }.keysIterator.toList.groupBy(_._1).mapValues(_.map(_._2)).withDefaultValue(Nil)

// %%
  val cFilter: Map[Int, List[Int]] = cyberPairs.map { case (dId, listCId) =>
    val mt: MetaData2 = meta2(idToRGB(dId))

    val eligible: List[Int] = listCId.filter { cId =>
      val cMeta = cyberMeta2(cyberMetaRev(cId))
      cMeta._2 <= mt.y && !cMeta._1.contains(mt.lastName)
    }

    (dId, eligible)
  }.filter(_._2.nonEmpty).withDefaultValue(Nil)

// %%
val cFilterKey = cFilter.keysIterator.toList

// %%
  object CopyKey {
    def fromRgb(id: String) = CopyKey(id, 0)

    def fromCyber(id: Int) = CopyKey("", id)
  }

case class CopyKey(rgbId: String, cyberId: Int) {
    override def toString: String = {
      if (rgbId == "") {
        s"Cyber($cyberId)"
      } else {
        s"Diss($rgbId)"
      }
    }
  }

// %%
  def extraGraph1(id: String, red: List[CopyItem2], cyber: List[Int]) = {
    val idInt: Int = RGBToId(id)
    val main: Set[Long] = dubsHash(idInt).toSet ++ dubsHashCyberDiss(idInt)
    val dissmap: Map[CopyKey, Set[Long]] = red.map(x => (CopyKey.fromRgb(x.destId), dubsHash(RGBToId(x.destId)).toSet)).toMap
    val cybermap: Map[CopyKey, Set[Long]] = cyber.map(x => (CopyKey.fromCyber(x), dubsHashCyber(x).toSet)).toMap
    val map = dissmap ++ cybermap

    val fold = (1 to map.size).foldLeft[(Set[Long], Set[CopyKey], List[(CopyKey, Int)])]((main, Set[CopyKey](), Nil)) {
      case ((set, used, acc), _) =>

        val max: (CopyKey, Set[Long]) = map.filterKeys(k => !used.contains(k)).maxBy(_._2.intersect(set).size)

        (set -- max._2, used + max._1, acc :+ (max._1, set.intersect(max._2).size))
    }

    fold._3
  }

// %%
    for (year <- 1980 to 2020) {
      val usefullRed = allReports.filter { x =>
        x.main.y == year && (x.red.nonEmpty)
      }.map { x =>
        val disbadName = disBad((x.main.lastName, x.main.y)).map(x => extractWorkNamefromDisbase(x._2)).mkString("|")
        val redCnt = x.red.map(_.size).sum
        val max = x.red.maxBy(_.size)
        val dissId: Int = RGBToId(x.main.id)

        val g = extraGraph1(x.main.id, x.red, cFilter(dissId))
        val gSum = g.map(_._2).sum
        val gSumBig = g.filter(_._2 >= DD).map(_._2).sum
        val gBiggest = g.head._2

        val cOthers = cFilter(dissId)

        val cyberCopy = cOthers.map { cId =>
          val size = cyberDubs((dissId, cId))
          val cMeta = cyberMeta2(cyberMetaRev(cId))

          val link = s"https://cyberleninka.ru/article/n/${cyberMetaRev(cId).dropRight(4)}"

          (link, cMeta, size, cId)
        }.sortBy(_._3)(Ordering[Int].reverse)


        if (disBad((x.main.lastName, x.main.y)).exists { t =>
          (jaccard(extractWorkNamefromDisbase(t._2), x.main.title) > 0.8) || (onlyNum(extractSpecfromDisbase(t._2)) == onlyNum(x.main.board)
        )}) {
          ""
        } else {
          List[String](x.main.lastName, x.main.y.toString, x.main.firstName, x.main.grade, x.main.sciArea, x.main.specs, x.main.board, disBad((x.main.lastName, x.main.y)).mkString(", "), x.main.title, disbadName, x.main.toString,
            redCnt.toString,
            max.size.toString,
            max.toString,
            x.red.map(o => (o.metaData, o.size)).mkString(", "),
            cyberCopy.mkString(", "),
            g.toString(),
            gSum.toString(),
            gSumBig.toString,
            gBiggest.toString,
            falseData(x.main.id)
          ).map(_.filterNot(_ == '\t')).mkString("\t")
        }
      }.toIterator.filter(_.nonEmpty)

      FileUtils.write(s"check${year}RedBigG14.csv", usefullRed)
    }

// %%
RGBToId("01002801678")

// %% [markdown]
// ###Extract common page header

// %%
    val m = scala.collection.mutable.Map[String, Int]().withDefaultValue(0)
    def fileHandleBib(fileName: String, fileId: Int) = {
      import scala.util.Try

      //      println(s"$fileName $fileId")
      Try {

        val a = Try {
          scala.io.Source.fromFile(fileName, "UTF-8").getLines().toList.mkString("").split(12.toChar)
        }.getOrElse {
          import java.io._
          val br = new BufferedReader(new InputStreamReader(
            new FileInputStream(fileName), "UTF-8"))
          br.lines().toArray.toList.map(_.toString).mkString("").split(12.toChar)
        }


        a.foreach { head =>
          val list = head.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)

          val head1 = list.head
          if (head1.size > 5) {
            m(head1) = m(head1) + 1
          }
          val head2 = list.take(2).mkString(" ")
          if (head2.size > 10) {
            m(head2) = m(head2) + 1
          }
          m(list.take(3).mkString(" ")) = m(list.take(3).mkString(" ")) + 1
        }
      }
    }

    def dirHandleBib(dir: String) = {
      println(dir)
      FileUtils.filesInDir(dir, x => x.endsWith(".txt")).iterator.foreach { file =>
        val fileName = file.name
        fileHandleBib(file.path, all(fileName))
      }

    }

// %%
    (0 to 999).foreach { idx =>
      dirHandleBib(s"d/data1/$idx")
    }

// %%
    val sortM = m.toList.filter(x => x._2 > 10).sortBy(_._2)(Ordering[Int].reverse)

// %%
    FileUtils.write("q", sortM.toIterator.map(_.toString()))

// %%
sortM.take(10).foreach(println)

// %%
        def hash(str: String, seed: Int): Int = {
          var res = 1
          for (c <- str) {
            res = res * seed + c.toInt
          }

          res
        }

// %%
    val bibList = List[String](
      "СПИСОК ЛИТЕРАТУРЫ", "СПИСОК ИСПОЛЬЗОВАННОЙ", "СПИСОК ИСПОЛЬЗУЕМОЙ", "СПИСОКЛИТЕРАТУРЫ", "УКАЗАТЕЛЬ ЛИТЕРАТУРЫ",
      "СПИСОК ЦИТИРУЕМОЙ", "ИСПОЛЬЗОВАННАЯ ЛИТЕРАТУРА", "БИБЛИОГРАФИЧЕСКИЙ СПИСОК", "СПИСОК ИСПОЛЬЗОВАННЫХ",
      "БИБЛИОГРАФИЧЕСКИЙ", "БИБЛИОГРАФИЯ", "СПИСОК ИСТОЧНИКОВ", "ЛИТЕРАТУРА")

    val endList = List[String]("ВЫВОДЫ", "ЗАКЛЮЧЕНИЕ")

        def convert(str: String): List[String] = {
          str.filter(ch => (ch >= 'а' && ch <= 'Я') || (ch >= '\u0410' && ch <= '\u044F') || ch == ' ' || ch == '\n').replace('\n', ' ').toUpperCase
            .split(" ").filter(_.nonEmpty).toList
        }


    import java.util.concurrent.atomic.AtomicInteger
    val st1: AtomicInteger = new AtomicInteger(0)
    val st2: AtomicInteger = new AtomicInteger(0)
    val st3: AtomicInteger = new AtomicInteger(0)
    val st4: AtomicInteger = new AtomicInteger(0)
    val cm = scala.collection.concurrent.TrieMap[(String, String, Int), Int]().withDefaultValue(0)




        def fileHandleToHash(fileName: String, fileId: Int): List[String] = {
          import scala.util.Try
          Try {

            val a: Array[String] = Try {
              scala.io.Source.fromFile(fileName, "UTF-8").getLines().toList.mkString("").split(12.toChar)
            }.getOrElse {
              import java.io._
              val br = new BufferedReader(new InputStreamReader(
                new FileInputStream(fileName), "UTF-8"))
              br.lines().toArray.toList.map(_.toString).mkString("").split(12.toChar)
            }


            val rev = a.zipWithIndex.reverse
            val zip = a.zipWithIndex

            val bib: Option[Int] = rev.take(rev.size / 2).find { case (str, _) =>
              val list = str.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)
              val head = list.mkString(" ")
              bibList.exists(prefix => head.startsWith(prefix))
            }.map(_._2)

            val end: Option[Int] = rev.take(rev.size / 2).find { case (str, _) =>
              val list = str.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)
              val head = list.mkString(" ")
              endList.exists(prefix => head.startsWith(prefix))
            }.map(_._2)
        val meta = meta2(all_back(fileId).dropRight(4))


        val toHash: Set[(String, Int)] = (bib, end) match {
          case (Some(b), Some(e)) if ((b > e) && (b - e < 20)) => st1.incrementAndGet(); cm((meta._type, meta.grade, 1)) = cm((meta._type, meta.grade, 1)) + 1; zip.slice(e, b).toSet
          case (Some(b), Some(e)) => st2.incrementAndGet(); cm((meta._type, meta.grade, 2)) = cm((meta._type, meta.grade, 2)) + 1; (zip.slice(e, e + 5) ++ zip.slice(b - 5, b)).toSet
          case (Some(b), None) => st3.incrementAndGet(); cm((meta._type, meta.grade, 3)) = cm((meta._type, meta.grade, 3)) + 1; (zip.slice(b - 5, b)).toSet
          case (None, Some(e)) => st4.incrementAndGet(); cm((meta._type, meta.grade, 4)) = cm((meta._type, meta.grade, 4)) + 1;(zip.slice(e, e + 5)).toSet
          case _ => Set[(String, Int)]()
        }

            val ss = toHash.toList.sortBy(_._2).map(x => x._1).foldLeft("")(_ + _)

            val list = convert(ss)
            list.sliding(5, 1).map { x =>
              val s1 = x.mkString(" ")
              s"${hash(s1, 5)}\t${hash(s1, 7)}\t$fileId"
            }.toList
          }.getOrElse(List[String]())
        }

        def dirHandleBibHash(dir: String, idx: Int) = {
          println(dir)
          val i: Iterator[String] = FileUtils.filesInDir(dir, x => x.endsWith(".txt")).iterator.flatMap { file =>
            val fileName = file.name
            fileHandleToHash(file.path, all(fileName))
          }

          FileUtils.write(s"$idx.b", i)

        }

// %%
// dirHandleBibHash("d/data1/0", 0)

// %%
(0 to 999).par.foreach { idx =>
    dirHandleBibHash(s"d/data1/$idx", idx)
}

// %%
st1
st2
st3
st4

cm
cm.toList.sortBy(_._2)(Ordering[Int].reverse).foreach(println)

// %%
st1. + st2 + st3 + st4

// %%
    val iter1: Iterator[String] = GroupIterator[String, String, List[String]](scala.io.Source.fromFile("sort.b").getLines(), line => {
      val split = line.split("\t")

      (split.take(2).mkString("\t"), List(line))
    },
      {
        (a, b) => a ++ b
      }
    ).filter(x => x._2.size >= 2 && x._2.size <= 5).flatMap(_._2)

    FileUtils.write("b.b", iter1)

// %%
    val bibMap = scala.collection.mutable.Map[(Int, Int), Int]().withDefaultValue(0)

    GroupIterator[String, String, List[String]](scala.io.Source.fromFile("b.b").getLines(), line => {
      val split = line.split("\t")

      (split.take(2).mkString("\t"), List(line))
    },
      {
        (a, b) => a ++ b
      }
    ).foreach { case (_, list) =>
      val ids = list.map (x => x.split("\t").last.toInt)
      ids.combinations(2).foreach {
        ll =>
          val ii = ll.head
          val jj = ll.last
          bibMap((ii, jj)) = bibMap((ii, jj)) + 1
          bibMap((jj, ii)) = bibMap((jj, ii)) + 1
      }
    }

// %%
    val sorted = bibMap.toList.sortBy(_._2)(Ordering[Int].reverse).filter(_._2 > 100)

// %%
lazy val forbidden = scala.io.Source.fromFile("dubfiles").getLines().flatMap(_.split("\t").drop(2).toList).map(_.split("/").last).map(x => all(x)).toSet
lazy val forbidden1 = scala.io.Source.fromFile("dubfiles").getLines().flatMap(_.split("\t").drop(2).toList).map(_.split("/").last).toSet

// %%
    val pres = sorted.map { case ((a, b), size) =>
      val atxt = all_back(a).dropRight(4)
      val btxt = all_back(b).dropRight(4)

      val ma = meta2(atxt)
      val mb = meta2(btxt)

      if (ma.lastName != mb.lastName && ma._type == "disser" && mb._type == "disser" && !forbidden.contains(a) && !forbidden.contains(b)) {
        if (ma.y > mb.y) {
          val dd = disBad((ma.lastName, ma.y)).mkString(", ")
          val ff = falseData(ma.id)
          s"${ma.lastName}\t${mb.lastName}\t$ma\t${ma.y}\t$mb\t$size\t$dd\t$ff"
        } else {
          val dd = disBad((mb.lastName, mb.y)).mkString(", ")
          val ff = falseData(mb.id)
          s"${mb.lastName}\t${ma.lastName}\t$mb\t${mb.y}\t$ma\t$size\t$dd\t$ff"
        }
      } else {
        ""
      }
    }.filter(_.nonEmpty)

    FileUtils.write("bib3.csv", pres.distinct.iterator)

// %%
sorted.size

// %% [markdown]
// ##TABLES

// %%
        def hash(str: String, seed: Int): Int = {
          var res = 1
          for (c <- str) {
            res = res * seed + c.toInt
          }

          res
        }


    def extractNum(str: String): List[String] = {
      val list = str.drop(5).dropRight(10).filterNot(x => x == ',' || x == '.').map(x => if (x.isDigit) x else ' ').split(" ").filter(_.nonEmpty).toList
      val res = list.filter { x =>
        (x.length < 10 && ((x.toLong < 1900 && x.toLong > 200) || (x.toLong > 2030)) || x.startsWith("0"))
      }.filterNot(x => x.forall(_ == '0')).filterNot { x => (x.startsWith("0") && x.size <= 3) || (x.startsWith("00") && x.size <= 4) }
      if (res.size <= 9) {
        List()
      } else {
        res
      }
    }


    def fileHandleToNum(fileName: String, fileId: Int): List[String] = {
      val bibList = List[String](
        "СПИСОК ЛИТЕРАТУРЫ", "СПИСОК ИСПОЛЬЗОВАННОЙ", "СПИСОК ИСПОЛЬЗУЕМОЙ", "СПИСОКЛИТЕРАТУРЫ", "УКАЗАТЕЛЬ ЛИТЕРАТУРЫ",
        "СПИСОК ЦИТИРУЕМОЙ", "ИСПОЛЬЗОВАННАЯ ЛИТЕРАТУРА", "БИБЛИОГРАФИЧЕСКИЙ СПИСОК", "СПИСОК ИСПОЛЬЗОВАННЫХ",
        "БИБЛИОГРАФИЧЕСКИЙ", "БИБЛИОГРАФИЯ", "СПИСОК ИСТОЧНИКОВ", "ЛИТЕРАТУРА")

      val endList = List[String]("ВЫВОДЫ", "ЗАКЛЮЧЕНИЕ")


      import scala.util.Try
      val numbers: List[(List[String], Int)] = Try {

        val a: Array[String] = Try {
          scala.io.Source.fromFile(fileName, "UTF-8").getLines().toList.mkString("").split(12.toChar)
        }.getOrElse {
          import java.io._
          val br = new BufferedReader(new InputStreamReader(
            new FileInputStream(fileName), "UTF-8"))
          br.lines().toArray.toList.map(_.toString).mkString("").split(12.toChar)
        }

        val zip = a.zipWithIndex
        val rev = zip.reverse

        val bib: Option[Int] = rev.take((rev.size * 3 / 4).toInt).find { case (str, _) =>
          val list = str.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)
          val head = list.mkString(" ")
          bibList.exists(prefix => head.startsWith(prefix))
        }.map(_._2)

        val end: Option[Int] = rev.take((rev.size * 3 / 4).toInt).find { case (str, _) =>
          val list = str.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)
          val head = list.mkString(" ")
          endList.exists(prefix => head.startsWith(prefix))
        }.map(_._2)

        val endPos = (bib, end) match {
          case (Some(b), Some(e)) => scala.math.min(b, e)
          case (None, Some(e)) => e
          case (Some(b), None) => b
          case _ => a.size - 10
        }

        val sub = zip.slice(50, endPos).filter { case (page, _) =>
          page.toUpperCase.contains("ТАБЛИЦ")
        }

        val res: List[(List[String], Int)] = sub.toList.map(x => (extractNum(x._1), x._2))
        res
      }.getOrElse(List())

      if (numbers.size >= 3) {
        numbers.flatMap { case (list, pageId) =>
          list.sliding(3, 1).toList.map { triple =>
            val str = triple.mkString(" ")
            s"${hash(str, 5)}\t${hash(str, 7)}\t$fileId\t$pageId"
          }
        }
      } else {
        List()
      }

    }

    def dirHandleNum(dir: String, idx: Int) = {
      println(dir)
      val i: Iterator[String] = FileUtils.filesInDir(dir, x => x.endsWith(".txt")).iterator.flatMap { file =>
        val fileName = file.name
        fileHandleToNum(file.path, all(fileName))
      }

      FileUtils.write(s"$idx.tt", i)

    }

// %%
(0 to 999).par.foreach { idx =>
    dirHandleNum(s"d/data1/$idx", idx)
}

// %%
    (0 to 999).grouped(10).foreach { list =>
      list.par.foreach { idx =>
              dirHandleNum(s"d/data1/$idx", idx)
      }
    }

// %%
    dirHandleNum(s"d/data1/10", 10)

// %%
    val iter1: Iterator[String] = GroupIterator[String, String, Vector[String]](scala.io.Source.fromFile("sort.t").getLines(), line => {
      val split = line.split("\t")

      (split.take(2).mkString("\t"), Vector(line))
    },
      {
        (a, b) => a ++ b
      }
    ).filter(x => x._2.size >= 2 && x._2.size <= 5).flatMap(_._2)

    FileUtils.write("tt.tt", iter1)

// %%
    val iter2: Iterator[String] = GroupIterator[String, String, Vector[String]](scala.io.Source.fromFile("qq.tt").getLines(), line => {
      val split = line.split("\t")

      (split.drop(2).mkString("\t"), Vector(line))
    },
      {
        (a, b) => a ++ b
      }
    ).filter(x => x._2.size >= 3).flatMap(_._2)

    FileUtils.write("ff.tt", iter2)

// %%
    //DocId, PageNum
    val tableSet = scala.collection.mutable.Set[(Int, Int)]()

    scala.io.Source.fromFile("ff.tt").getLines().foreach { line =>
      val split = line.split("\t")
      tableSet.add((split(2).toInt, split(3).toInt))
    }

// %%
    val talbeMap = scala.collection.mutable.Map[(Int, Int), Int]().withDefaultValue(0)

    GroupIterator[String, String, List[String]](scala.io.Source.fromFile("tt.tt").getLines(), line => {
      val split = line.split("\t")

      (split.take(2).mkString("\t"), List(line))
    },
      {
        (a, b) => a ++ b
      }
    ).foreach { case (_, list) =>
      val ids = list.map (x => x.split("\t").last.toInt)
      ids.combinations(2).foreach {
        ll =>
          val ii = ll.head
          val jj = ll.last
          talbeMap((ii, jj)) = talbeMap((ii, jj)) + 1
          talbeMap((jj, ii)) = talbeMap((jj, ii)) + 1
      }
    }

// %%
    val sortedTable = talbeMap.toList.filter(_._2 > 50).sortBy(_._2)(Ordering[Int].reverse)

// %%
def fullPath(fileName: String): String = {
    val dir = loc(fileName)
    s"d/${dir}/$fileName"
}

// %%
    //doc1, page1, doc2, page2
    val tablePageMap = scala.collection.mutable.Map[(Int, Int, Int, Int), Int]().withDefaultValue(0)
    GroupIterator[String, String, List[String]](scala.io.Source.fromFile("tt.tt").getLines(), line => {
      val split = line.split("\t")

      (split.take(2).mkString("\t"), List(line))
    },
      {
        (a, b) => a ++ b
      }
    ).foreach { case (_, list) =>
      val pages = list.map (x => x.split("\t").last.toInt)
      val ids = list.map (x => x.split("\t").dropRight(1).last.toInt)
      ids.zip(pages).combinations(2).foreach {
        ll =>

          val ii = ll.head
          val jj = ll.last
          if (tableSet.contains(ii._1, ii._2) && tableSet.contains(jj._1, jj._2)) {
            tablePageMap((ii._1, ii._2, jj._1, jj._2)) = tablePageMap((ii._1, ii._2, jj._1, jj._2)) + 1
            tablePageMap((jj._1, jj._2, ii._1, ii._2)) = tablePageMap((jj._1, jj._2, ii._1, ii._2)) + 1
          }
      }
    }

// %%
    val resTable = tablePageMap.filter { case (_, v) => v >= 10 }.filter { case ((a, _, c, _), _) => a != c}

// %%
    val resTableByPage: Map[(Int, Int), List[((Int, Int), Int)]] = resTable.toList.groupBy(x => (x._1._1, x._1._3)).mapValues(x => x.map(z => ((z._1._2, z._1._4), z._2)))
    val resTableCount: Map[(Int, Int), Int] = resTableByPage.mapValues(x => x.map(_._2).sum)

// %%
  lazy val workSizes: Map[Int, String] = scala.io.Source.fromFile("size.size").getLines.map { line =>
    val split = line.split("\t")
    split(0).toInt -> split(1)
  }.toMap

  lazy val workSizesSI: Map[Int, Int] = workSizes.mapValues(_.split("-").last.toInt + 1)

// %%
    val pres = resTableCount.toList.sortBy(_._2)(Ordering[Int].reverse).map { case ((a, b), size) =>
      Try {
        val atxt = all_back(a).dropRight(4)
        val btxt = all_back(b).dropRight(4)

        var ma = meta2(atxt)
        var mb = meta2(btxt)

                  

          val disb = disBad((ma.lastName, ma.y)).find { t =>
  (jaccard(extractWorkNamefromDisbase(t._2), ma.title) > 0.8) || (onlyNum(extractSpecfromDisbase(t._2)) == onlyNum(ma.board)
    )}.map(_.toString()).getOrElse("")

        if (ma.lastName != mb.lastName && ma._type == "disser" && mb._type == "disser" && !forbidden.contains(a) && !forbidden.contains(b)) {
//           if (ma.y >= mb.y && disb == "") {
          if (ma.y >= mb.y) {
            val ff = falseData(ma.id)
            val pages = resTableByPage((a, b)).sortBy(_._1._1).map(x => ((x._1._1 + 1, x._1._2 + 1), x._2))
            s"${ma.lastName}\t${mb.lastName}\t${ma.sciArea}\t$ma\t${ma.y}\t$mb\t${disb}\t$size\t${workSizes(a)}|${workSizes(b)}\t${pages.mkString(", ")}\t$disb\t$ff"
          } else {
            ""
          }



        } else {
          ""
        }
      }.getOrElse("")
    }.filter(_.nonEmpty)

    FileUtils.write("table5.csv", pres.distinct.iterator)

// %%
    def extractPageContext(fileName: String, page: Int): List[String] = {
      import scala.util.Try
      Try {

        val a: Array[String] = Try {
          scala.io.Source.fromFile(fileName, "UTF-8").getLines().toList.mkString("").split(12.toChar)
        }.getOrElse {
          import java.io._
          val br = new BufferedReader(new InputStreamReader(
            new FileInputStream(fileName), "UTF-8"))
          br.lines().toArray.toList.map(_.toString).mkString("").split(12.toChar)
        }


        val p = a(page).toUpperCase

        val sp: List[String] = p.filter(x => x.isLetterOrDigit || x == ' ').split(" ").filter(_.nonEmpty).mkString(" ").split("ТАБЛИЦ").toList

        val res: List[String] = (1 to sp.size - 1).map { idx =>
          s"${sp.take(idx).mkString("ТАБЛИЦ").takeRight(1)}ТАБЛИЦ${sp.drop(idx).mkString("ТАБЛИЦ").take(150)}"

        }.toList


//        val res: List[String] = sp.sliding(2).toList.map { pair =>
//          s"${pair.head.takeRight(30)}ТАБЛИЦ${pair.last.take(150)}"
//        }

        res
      }.getOrElse(List[String]("*********"))
    }


    def extract(fst: String, snd: String, fstPage: Int, sndPage: Int): List[String] = {
      val fstList: List[String] = extractPageContext(fullPath(fst), fstPage).map(x => s"${fstPage + 1}: ${x}")
      val sndList: List[String] = extractPageContext(fullPath(snd), sndPage).map(x => s"${sndPage + 1}: ${x}")
        
      val add = scala.math.max(fstList.size, sndList.size) - scala.math.min(fstList.size, sndList.size)

      val (f: List[String], s: List[String]) = (fstList.size, sndList.size) match {
        case (a, b) if a < b => (fstList ++ List.fill[String](add)(""), sndList)
        case _ => (fstList, sndList ++ List.fill[String](add)(""))
      }

      f.zip(s).map { case (a, b) => s"\t\t\t\t\t${a}\t${b}"
      }

    }

// %%
    val pres: List[String] = resTableCount.toList.sortBy(_._2)(Ordering[Int].reverse).flatMap { case ((a, b), size) =>
      Try {
        val atxt = all_back(a).dropRight(4)
        val btxt = all_back(b).dropRight(4)

        var ma = meta2(atxt)
        var mb = meta2(btxt)

        var aa = a
        var bb = b
                  

          val disb = disBad((ma.lastName, ma.y)).find { t =>
  (jaccard(extractWorkNamefromDisbase(t._2), ma.title) > 0.8) || (onlyNum(extractSpecfromDisbase(t._2)) == onlyNum(ma.board)
    )}.map(_.toString()).getOrElse("")

        if (ma.lastName != mb.lastName && ma._type == "disser" && mb._type == "disser" && !forbidden.contains(a) && !forbidden.contains(b)
        && ma.year == "2012" && ma.sciArea != "экономических"
           ) {
          if (ma.y >= mb.y && disb == "") {
            val ff = falseData(ma.id)
            val pages = resTableByPage((aa, bb)).sortBy(_._1._1)
              
            val list = pages.flatMap { case ((p1, p2), size) =>
              extract(all_back(a), all_back(b), p1, p2)                
            }
              
            s"${ma.lastName}-${mb.lastName}\t${atxt}-${btxt}\t${ma.y}\t${mb.y}\t${ma.sciArea}" +: list

              
//             s"${ma.lastName}\t${mb.lastName}\t${ma.sciArea}\t$ma\t${ma.y}\t$mb\t$size\t${sizes(a)}|${sizes(b)}\t${pages.mkString(", ")}\t$disb\t$ff"
          } else {
            Nil
          }

        } else {
          Nil
        }
      }.getOrElse(Nil)
    }

    FileUtils.write("description4Other.csv", pres.iterator)

// %%
def convertNg(str: String): String = {
      str.filter(ch => ch == ' ' || (ch >= 'а' && ch <= 'Я') || (ch >= '\u0410' && ch <= '\u044F')).toUpperCase
    }


    def fileHandleSize(fileName: String, fileId: Int): String = {
      val bibList = List[String](
        "СПИСОК ЛИТЕРАТУРЫ", "СПИСОК ИСПОЛЬЗОВАННОЙ", "СПИСОК ИСПОЛЬЗУЕМОЙ", "СПИСОКЛИТЕРАТУРЫ", "УКАЗАТЕЛЬ ЛИТЕРАТУРЫ",
        "СПИСОК ЦИТИРУЕМОЙ", "ИСПОЛЬЗОВАННАЯ ЛИТЕРАТУРА", "БИБЛИОГРАФИЧЕСКИЙ СПИСОК", "СПИСОК ИСПОЛЬЗОВАННЫХ",
        "БИБЛИОГРАФИЧЕСКИЙ", "БИБЛИОГРАФИЯ", "СПИСОК ИСТОЧНИКОВ", "ЛИТЕРАТУРА")

      val endList = List[String]("ВЫВОДЫ", "ЗАКЛЮЧЕНИЕ")


      import scala.util.Try
      Try {

        val a: Array[String] = Try {
          scala.io.Source.fromFile(fileName, "UTF-8").getLines().toList.mkString("").split(12.toChar)
        }.getOrElse {
          import java.io._
          val br = new BufferedReader(new InputStreamReader(
            new FileInputStream(fileName), "UTF-8"))
          br.lines().toArray.toList.map(_.toString).mkString("").split(12.toChar)
        }

        val zip = a.zipWithIndex
        val rev = zip.reverse

        val bib: Option[Int] = rev.take((rev.size * 3 / 4).toInt).find { case (str, _) =>
          val list = str.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)
          val head = list.mkString(" ")
          bibList.exists(prefix => head.startsWith(prefix))
        }.map(_._2)

        val end: Option[Int] = rev.take((rev.size * 3 / 4).toInt).find { case (str, _) =>
          val list = str.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)
          val head = list.mkString(" ")
          endList.exists(prefix => head.startsWith(prefix))
        }.map(_._2)

        val endPos = (bib, end) match {
          case (Some(b), Some(e)) => scala.math.min(b, e)
          case (None, Some(e)) => e
          case (Some(b), None) => b
          case _ => a.size - 10
        }


        val text: String = a.slice(4, endPos).mkString(" ").replace(s"${173.toChar} ", "")

        val con = convertNg(text).split(" ").filter(_.nonEmpty)


        s"$fileId\t${a.size}-${end.getOrElse(0)}-${bib.getOrElse(0)}-${con.size}"
      }.getOrElse("")


    }

def dirHandleSize(dir: String, idx: Int) = {
      println(dir)
      val i: Iterator[String] = FileUtils.filesInDir(dir, x => x.endsWith(".txt")).iterator.flatMap { file =>
        val fileName = file.name
        List(fileHandleSize(file.path, all(fileName)))
      }

      FileUtils.write(s"$idx.size", i)

    }

// %%
    dirHandleSize(s"d/data1/0", 0)

// %%
(0 to 999).par.foreach { idx =>
    dirHandleSize(s"d/data1/$idx", idx)
}

// %% [markdown]
// #ngram

// %%
    def hash(str: String, seed: Int): Int = {
      var res = 1
      for (c <- str) {
        res = res * seed + c.toInt
      }

      res
    }


def convertNg(str: String): String = {
      str.filter(ch => ch == ' ' || (ch >= 'а' && ch <= 'Я') || (ch >= '\u0410' && ch <= '\u044F')).toUpperCase
    }


    def fileNgram(fileName: String, fileId: Int, mapReduceFilter: Int = 0): Iterator[String] = {
      val bibList = List[String](
        "СПИСОК ЛИТЕРАТУРЫ", "СПИСОК ИСПОЛЬЗОВАННОЙ", "СПИСОК ИСПОЛЬЗУЕМОЙ", "СПИСОКЛИТЕРАТУРЫ", "УКАЗАТЕЛЬ ЛИТЕРАТУРЫ",
        "СПИСОК ЦИТИРУЕМОЙ", "ИСПОЛЬЗОВАННАЯ ЛИТЕРАТУРА", "БИБЛИОГРАФИЧЕСКИЙ СПИСОК", "СПИСОК ИСПОЛЬЗОВАННЫХ",
        "БИБЛИОГРАФИЧЕСКИЙ", "БИБЛИОГРАФИЯ", "СПИСОК ИСТОЧНИКОВ", "ЛИТЕРАТУРА")

      val endList = List[String]("ВЫВОДЫ", "ЗАКЛЮЧЕНИЕ")


      import scala.util.Try
      Try {
        val a: Array[String] = Try {
          val fromFile = scala.io.Source.fromFile(fileName, "UTF-8")
          val res = fromFile.getLines().toList.mkString(" ").split(12.toChar)
          fromFile.close()
          res
        }.getOrElse {
          import java.io._
          val br = new BufferedReader(new InputStreamReader(
            new FileInputStream(fileName), "UTF-8"))
          br.lines().toArray.toList.map(_.toString).mkString("").split(12.toChar)
        }

        val zip = a.zipWithIndex
        val rev = zip.reverse

        val bib: Option[Int] = rev.take((rev.size * 3 / 4).toInt).find { case (str, _) =>
          val list = str.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)
          val head = list.mkString(" ")
          bibList.exists(prefix => head.startsWith(prefix))
        }.map(_._2)

        val end: Option[Int] = rev.take((rev.size * 3 / 4).toInt).find { case (str, _) =>
          val list = str.take(100).toUpperCase.filter(x => x.isLetter || x == ' ').split(" ").filter(_.nonEmpty)
          val head = list.mkString(" ")
          endList.exists(prefix => head.startsWith(prefix))
        }.map(_._2)

        val endPos = (bib, end) match {
          case (Some(b), Some(e)) => scala.math.min(b, e)
          case (None, Some(e)) => e
          case (Some(b), None) => b
          case _ => a.size - 10
        }


        val text: String = a.slice(4, endPos).mkString(" ").replace(s"${173.toChar} ", "")

        val conv = convertNg(text).split(" ").filter(_.nonEmpty).toVector

        val slid: Iterator[Vector[String]] = conv.sliding(6)


        val res: Iterator[String] = slid.map { ngram =>
          val ng = ngram.mkString(" ")
          val h5 = hash(ng, 5)
          val h7 = hash(ng, 7)
          val sum = (h5.toLong << 32) + h7
          if ((scala.math.abs(sum) % 10) == mapReduceFilter) {
            s"$h5\t$h7\t$fileId"
          } else {
            ""
          }
        }.filter(_.nonEmpty)

        res
      }.getOrElse(Iterator.empty)


    }

    
    def dirNgram(dir: String, idx: Int, mapReduceFilter: Int = 0) = {
      println(dir)
      val i: Iterator[String] = FileUtils.filesInDir(dir, x => x.endsWith(".txt")).iterator.flatMap { file =>
        val fileName = file.name
        fileNgram(file.path, all(fileName), mapReduceFilter)
      }

      FileUtils.write(s"$idx.ng", i)
    }

// %%
 dirNgram("d/data1/995", 995, 0)

// %%
    (0 to 999).grouped(30).foreach { list =>
      list.par.foreach { idx =>
              dirNgram(s"d/data1/$idx", idx, ???)
      }
    }

// %%
  (0 to 999).par.foreach { idx =>
            dirNgram(s"d/data1/$idx", idx, 9)
  }

// %%
//CYBER

// %%
  val cyberMeta: Map[String, Int] = scala.io.Source.fromFile("meta.c").getLines().map { line =>
    val split = line.split("\t")
    (split.last, split.head.toInt)
  }.toMap

// %%
    def hash(str: String, seed: Int): Int = {
      var res = 1
      for (c <- str) {
        res = res * seed + c.toInt
      }

      res
    }


    def convertNg(str: String): String = {
      str.filter(ch => ch == ' ' || (ch >= 'а' && ch <= 'Я') || (ch >= '\u0410' && ch <= '\u044F')).toUpperCase
    }


    def fileNgramCyber(fileName: String, fileId: Int, mapReduceFilter: Int = 0): Iterator[String] = {
      val bibList = List[String](
        "СПИСОК ЛИТЕРАТУРЫ", "СПИСОК ИСПОЛЬЗОВАННОЙ", "СПИСОК ИСПОЛЬЗУЕМОЙ", "СПИСОКЛИТЕРАТУРЫ", "УКАЗАТЕЛЬ ЛИТЕРАТУРЫ",
        "СПИСОК ЦИТИРУЕМОЙ", "ИСПОЛЬЗОВАННАЯ ЛИТЕРАТУРА", "БИБЛИОГРАФИЧЕСКИЙ СПИСОК", "СПИСОК ИСПОЛЬЗОВАННЫХ",
        "БИБЛИОГРАФИЧЕСКИЙ", "БИБЛИОГРАФИЯ", "СПИСОК ИСТОЧНИКОВ", "ЛИТЕРАТУРА")


      import scala.util.Try
      Try {
        val a: String = Try {
          val fromFile = scala.io.Source.fromFile(fileName, "UTF-8")
          val res = fromFile.getLines().toList.mkString(" ")
          fromFile.close()
          res
        }.getOrElse {
          import java.io._
          val br = new BufferedReader(new InputStreamReader(
            new FileInputStream(fileName), "UTF-8"))
          br.lines().toArray.toList.map(_.toString).mkString(" ")
        }

        val mainText = convertNg(a).split(" ").filter(_.nonEmpty).mkString(" ")
        val rev = mainText.reverse


        val bibIdxs = bibList.map { phrase =>
          rev.indexOf(phrase.reverse)
        }.filter(_ != -1)
        val bibIdx = if (bibIdxs.nonEmpty) {
          bibIdxs.min
        } else {
          -1
        }


        val text: String = if (bibIdx != -1) {
          mainText.dropRight(bibIdx)
        } else {
          mainText
        }

        val slid: Iterator[Vector[String]] = text.split(" ").toVector.sliding(6)

        val res: Iterator[String] = slid.map { ngram =>
          val ng = ngram.mkString(" ")
          val h5 = hash(ng, 5)
          val h7 = hash(ng, 7)
          val sum = (h5.toLong << 32) + h7
          if ((scala.math.abs(sum) % 10) == mapReduceFilter) {
            s"$h5\t$h7\t$fileId\t-1"
          } else {
            ""
          }
        }.filter(_.nonEmpty)

        res
      }.getOrElse(Iterator.empty)


    }

    def dirNgramCyber(dir: String, idx: Int, mapReduceFilter: Int = 0) = {
      println(dir)
      val i: Iterator[String] = FileUtils.filesInDir(dir, x => x.endsWith(".txt")).iterator.flatMap { file =>
        val fileName = file.name
        if (cyberMeta.contains(fileName)) {
          fileNgramCyber(file.path, cyberMeta(fileName), mapReduceFilter)
        } else {
          Iterator.empty
        }
      }

      FileUtils.write(s"$idx.cy", i)
    }

// %%
dirNgramCyber("ccc/0", 0, 0)

// %%
    (960 to 999).grouped(30).foreach { list =>
      list.par.foreach { idx =>
              dirNgramCyber(s"ccc/$idx", idx, 0)
      }
    }

// %%
  (0 to 999).par.foreach { idx =>
            dirNgramCyber(s"ccc/$idx", idx, 9)
  }

// %%
    def join(d: Int) = {
      val iter1: Iterator[String] = GroupIterator[String, String, Vector[String]](scala.io.Source.fromFile(s"f$d").getLines(), line => {
        val split = line.split("\t")

        (split.take(2).mkString("\t"), Vector(line))
      },
        {
          (a, b) => a ++ b
        }
      ).filter(x => x._2.size >= 2 && x._2.size <= 6).flatMap(_._2)

      FileUtils.write(s"filter$d", iter1)

    }

// %%
    val d = 6
    val iter1: Iterator[String] = GroupIterator[String, String, Vector[String]](scala.io.Source.fromFile(s"f$d").getLines(), line => {
      val split = line.split("\t")

      (split.take(2).mkString("\t"), Vector(line))
    },
      {
        (a, b) => a ++ b
      }
    ).filter(x => x._2.size >= 2 && x._2.size <= 6).flatMap(_._2)

    FileUtils.write(s"filter$d", iter1)

// %%
    val d = 7
    val iter1: Iterator[String] = GroupIterator[String, String, Vector[String]](scala.io.Source.fromFile(s"f$d").getLines(), line => {
      val split = line.split("\t")

      (split.take(2).mkString("\t"), Vector(line))
    },
      {
        (a, b) => a ++ b
      }
    ).filter(x => x._2.size >= 2 && x._2.size <= 6).flatMap(_._2)

    FileUtils.write(s"filter$d", iter1)

// %%
import scala.collection.mutable.ArrayBuffer

// %%
  def trav(idx: Int) = {
    val dis = Array.fill[ArrayBuffer[String]](1000)(ArrayBuffer[String]())
    val cyb = Array.fill[ArrayBuffer[String]](1000)(ArrayBuffer[String]())


    val alls = scala.io.Source.fromFile(s"filter$idx").getLines()

    alls.foreach { line =>
      val split = line.split("\t")
      Try {

        val id = split(2).toInt % 1000

        if (id >= 0) {
          if (split.size == 4) {
            cyb(id).append(split.dropRight(1).mkString("\t"))

            if (cyb(id).length == 1000) {
              FileUtils.appendLine(s"cc/c$id", cyb(id).mkString("\n"))
              cyb(id) = ArrayBuffer[String]()
            }
          } else {
            dis(id).append(line)
            if (dis(id).length == 1000) {
              FileUtils.appendLine(s"dd/d$id", dis(id).mkString("\n"))
              dis(id) = ArrayBuffer[String]()
            }
          }
        }
      }
    }


    for (id <- 0 to 999) {
      FileUtils.appendLine(s"cc/c$id", cyb(id).mkString("\n"))
      FileUtils.appendLine(s"dd/d$id", dis(id).mkString("\n"))
    }
  }

// %%
  for (i <- 0 to 9) {
    trav(i)
  }

// %%
  def fileRevolve(fileName: String, writeTo: String) = {
    val d = scala.io.Source.fromFile(fileName).getLines().filter(_.nonEmpty).map { line =>
      val a = line.split("\t").map(_.toInt)

      (a.last, (a(0), a(1)))
    }.toVector

    val iter: Iterator[String] = d.groupBy(_._1).mapValues(_.map(_._2)).iterator.map { case (fileId, vec) =>
      s"$fileId\t${vec.map(x => s"${x._1} ${x._2}").mkString("\t")}"
    }

    FileUtils.write(writeTo, iter)
  }

// %%
fileRevolve(s"dd/d0", s"dd/0.dd")

// %%
  for (id <- 0 to 999) {
    fileRevolve(s"dd/d$id", s"dd/$id.dd")
  }

// %%
  for (id <- 0 to 999) {
    fileRevolve(s"cc/c$id", s"cc/$id.cc")
  }

// %%
  def size(fileName: String): Iterator[(Int, Int)] = {
    scala.io.Source.fromFile(fileName).getLines().map { line =>
      val split = line.split("\t")
      split.head.toInt -> (split.size - 1)
    }
  }

// %%
  val dsize = (0 to 999).iterator.flatMap(id => size(s"dd/$id.dd")).map(x => s"${x._1}\t${x._2}")

  FileUtils.write("disSize", dsize)

// %%
  val dsize = (0 to 999).iterator.flatMap(id => size(s"cc/$id.cc")).map(x => s"${x._1}\t${x._2}")

  FileUtils.write("cyberSize", dsize)

// %%
    lazy val dissSize: Map[Int, Int] = scala.io.Source.fromFile("disSize").getLines().map { line =>
      val split = line.split("\t").map(_.toInt)
      split.head -> split.last
    }.toMap.withDefaultValue(0)

    lazy val cyberSize: Map[Int, Int] = scala.io.Source.fromFile("cyberSize").getLines().map { line =>
      val split = line.split("\t").map(_.toInt)
      split.head -> split.last
    }.toMap.withDefaultValue(0)

// %%
    object BaseRef1 {
      def year(baseRef: BaseR): Int = {
        baseRef match {
          case DissRef(id) => meta2(all_back(id).dropRight(4)).y
          case CyberRef(id) =>
            val path = cyberMetaRev(id)
            cyberMeta2(path)._2
        }
      }

      def getLastName(dissRef: DissRef): String = {
        meta2(all_back(dissRef.id).dropRight(4)).lastName
      }

      def diffLastName(baseRef: BaseR, lastName: String): Boolean = {
        baseRef match {
          case x@DissRef(id) => getLastName(x) != lastName
          case CyberRef(id) =>
            val path = cyberMetaRev(id)
            !cyberMeta2(path)._1.contains(lastName)
        }

      }
    }

// %%
    sealed trait BaseR {}

    case class DissRef(id: Int) extends BaseR {}

    case class CyberRef(id: Int) extends BaseR {}

// %%
    val ngMap = scala.collection.mutable.Map[(BaseR, BaseR), Int]().withDefaultValue(0)

    GroupIterator[String, String, Vector[String]](scala.io.Source.fromFile("filter0").getLines(), line => {
      val split = line.split("\t")

      (split.take(2).mkString("\t"), Vector(line))
    },
      {
        (a, b) => a ++ b
      }
    ).foreach { case (_, list) =>
      val ids = list.map { x =>
        val sp = x.split("\t")
        val id = sp(2).toInt

        if (sp.size == 4) {
          CyberRef(id)
        } else {
          DissRef(id)
        }
      }
      ids.combinations(2).foreach {
        ll =>
          val ii = ll.head
          val jj = ll.last
          ngMap((ii, jj)) = ngMap((ii, jj)) + 1
          ngMap((jj, ii)) = ngMap((jj, ii)) + 1
      }
    }

// %%
    val histSize = 10000
    val histogram = Array.fill(histSize)(0)

    ngMap.valuesIterator.foreach { v =>
      if (v < histSize) {
        histogram(v) = histogram(v) + 1
      }
    }

    val histIter = histogram.zipWithIndex.iterator.map(x => s"${x._1}\t${x._2}")
    FileUtils.write("hist.hist", histIter)

// %%
    val ngMapFilter = ngMap.filter { case (_, v) =>
      v >= 7
    }

// %%
    val ngIter = ngMapFilter.iterator.map { case ((a, b), v) =>
      (a, b) match {
        case (DissRef(ida), DissRef(idb)) => s"$ida\t$idb\t$v"
        case (DissRef(ida), CyberRef(idb)) => s"$ida\t${-idb}\t$v"
        case (CyberRef(ida), CyberRef(idb)) => s"${-ida}\t${-idb}\t$v"
        case (CyberRef(ida), DissRef(idb)) => s"${-ida}\t$idb\t$v"
      }
    }
    
    FileUtils.write("ngMap7", ngIter)

// %%
ngMapFilter.size

// %%
    def fromId(id: Int): BaseR = {
      if (id < 0) {
        CyberRef(-id)
      } else {
        DissRef(id)
      }
    }

// %%
    val ngRealMap = scala.collection.mutable.Map[(BaseR, BaseR), Int]().withDefaultValue(0)

    scala.io.Source.fromFile("ngMap").getLines.foreach { line =>
      val split = line.split("\t").map(_.toInt)
      if (split.last >= 50)
        ngRealMap((fromId(split.head), fromId(split(1)))) = split.last
    }

    val ngGrouped: Map[BaseR, Vector[BaseR]] = ngRealMap.toVector.groupBy(_._1._1).mapValues(_.map(x => x._1._2))

// %%
ngGrouped.size

// %%
//     val res: Iterator[String] = ngGrouped.iterator.flatMap { case (x : BaseR, vec: Vector[BaseR]) =>
//       x match {
//         case id: DissRef =>
//           val meta = getDissMeta(id.id)
//           val disbad = findDisBad(meta)
//           val lastName: String = BaseRef1.getLastName(id)
//           val year = BaseRef1.year(x)
//           val filter = vec.filter { item: BaseR =>
//             BaseRef1.diffLastName(item, lastName) && year >= BaseRef1.year(item)
//           }

//           val sizes: Vector[Int] = filter.map(x => ngRealMap(id, x))

//           if (meta.y == 2011 && filter.nonEmpty) {
//             val list = List[String](meta.lastName, meta.y.toString, meta.firstName, meta.grade, meta.sciArea, meta.specs, meta.board, disbad, meta.title, meta.toString, filter.mkString(", "), sizes.mkString(", "))

//             Some(list.mkString("\t"))
//           } else {
//             None
//           }
//         case _ => None
//       }

//     }

//     FileUtils.write("res.csv", res)

// %%
  def readHash(file: String, id: Int): Set[String] = {
    Try {
      val iter = scala.io.Source.fromFile(file).getLines().flatMap { line =>
        val split = line.split("\t")
        val idx = split.head.toInt
        if (idx == id) {
          Some(split.drop(1).toSet)
        } else {
          None
        }
      }

      iter.take(1).toList.headOption.getOrElse(Set())
    }.getOrElse(Set())
  }


  def getHashes(baseR: BaseR): Set[String] = {
    val (id, fileName) = baseR match {
      case DissRef(id) => (id, s"ddd/${id % 1000}/$id.ddd")
      case CyberRef(id) => (id, s"ccc/${id % 1000}/$id.ccc")
    }

    readHash(fileName, id)
  }

// %%
val threshold = 150

def extraGraphNg(mainHash: Set[String], items: Map[BaseR, Set[String]]): List[(BaseR, Int)] = {
    val fold = (1 to items.size).foldLeft[(Set[String], Set[BaseR], List[(BaseR, Int)])]((mainHash, Set[BaseR](), Nil)) {
      case ((set, used, acc), _) =>

        val max: (BaseR, Set[String]) = items.filterKeys(k => !used.contains(k)).maxBy(_._2.intersect(set).size)

        (set -- max._2, used + max._1, acc :+ (max._1, set.intersect(max._2).size))
    }

    fold._3.filter(_._2 >= threshold)
  }

// %%
  object RefInfo {
    def getShortInfo(baseR: BaseR): String = {
      baseR match {
        case DissRef(id) => s"Diss(${all_back(id).dropRight(4)})"
        case CyberRef(id) => s"Cyber($id)"
      }
    }

    def getLongInfo(baseR: BaseR): String = {
      baseR match {
        case DissRef(id) => s"Diss(${getDissMeta(id)})"
        case CyberRef(id) =>
          val link = s"https://cyberleninka.ru/article/n/${cyberMetaRev(id).dropRight(4)}"
          val cmeta = cyberMeta2(cyberMetaRev(id))
          s"Cyber($id, $cmeta, $link)"
      }
    }

  }

// %%
  def extraDotGraph(main: BaseR, mainHash: Set[String], items: Map[BaseR, Set[String]]): String = {
    val alls: Map[BaseR, Set[String]] = items + (main -> mainHash)

    val edges = alls.keySet.toList.combinations(2).toList.flatMap { pair: List[BaseR] =>
      val fst = pair.head
      val snd = pair.last
      val size = (alls(fst) intersect alls(snd)).size
      if (size >= 150) {
        val (f, s, ar, ex) = (BaseRef1.year(fst), BaseRef1.year(snd)) match {
          case (a, b) if a < b => (fst, snd, "->", "")
          case (a, b) if a > b => (snd, fst, "->", "")
          case (a, b) if a == b => (snd, fst, "->", "dir=both")
        }
        Some(s""" "${RefInfo.getShortInfo(f)}" $ar "${RefInfo.getShortInfo(s)}" [label="$size" $ex]; """)
      } else {
        None
      }
    }.mkString("\n")

    s"""
       |digraph G {
       |  {
       |    node [];
       |    "${RefInfo.getShortInfo(main)}" [shape = polygon];
       |  }
       |
       |  $edges
       |}
       |""".stripMargin.replace("\n", "")
  }

// %%
val ngVector = ngGrouped.toVector
  for (year <- 2010 to 2013) {
    val res: Vector[String] = ngVector.par.flatMap { case (x: BaseR, vec: Vector[BaseR]) =>
      Try {
        x match {
          case id: DissRef =>
            val meta = getDissMeta(id.id)
            if (meta.y == year) {
              val disbad = findDisBad(meta)
              val lastName: String = BaseRef1.getLastName(id)

              val year = BaseRef1.year(x)
              val filter = vec.filter { item: BaseR =>
                BaseRef1.diffLastName(item, lastName) && year >= BaseRef1.year(item)
              }


                if (meta.y == year && filter.nonEmpty && disbad == "") {
//               if (filter.nonEmpty) {
                val mainHash = getHashes(x)
                val otherHash = filter.map(x => x -> getHashes(x)).toMap
                val extraGraph = extraGraphNg(mainHash, otherHash)
                val debug = if (filter.size > 1)
                  extraDotGraph(x, mainHash, otherHash)
                else ""

                val extraGraphShow = extraGraph.map(x => (RefInfo.getShortInfo(x._1), x._2))
                val extraLongShow = extraGraph.map(x => (RefInfo.getLongInfo(x._1), x._2))

                val sizes = extraGraphShow.map(_._2)
                val sum = sizes.sum
                val max = sizes.max
                val len = sizes.size
                val falsedat = falseData(meta.id)
                    
                val ratio = sum.toDouble / workSizesSI(id.id)
                    

                val list = List[String](meta.lastName, meta.y.toString, meta.firstName, meta.grade, meta.sciArea, meta.specs, meta.board, disbad, meta.title, meta.toString, extraLongShow.mkString(", "), extraGraphShow.mkString(", "), len.toString, sum.toString, max.toString, falsedat, workSizes(id.id), ratio.toString,  debug)

                Some(list.map(_.replace("\t", "")).mkString("\t"))
              } else {
                None
              }
            } else {
              None
            }

          case _ => None
        }

      }.getOrElse {
        FileUtils.appendLine("errors.log", x.toString);
        None
      }
    }.toVector

    FileUtils.write(s"ngram${year}woDis.csv", res.iterator)

  }

// %%
getCyberMeta(1)

// %%
  for (y <- 1980 to 2021) {
    val res: Vector[String] = ngVector.par.flatMap { case (x: BaseR, vec: Vector[BaseR]) =>
      Try {
        x match {
          case id: CyberRef =>
            val meta = getCyberMeta(id.id)

            val year = BaseRef1.year(x)

            if (year == y) {
              val filter = vec.filter { item: BaseR =>
                year >= BaseRef1.year(item)
              }

              if (filter.nonEmpty) {
                val mainHash = getHashes(x)
                val otherHash = filter.map(x => x -> getHashes(x)).toMap
                val extraGraph = extraGraphNg(mainHash, otherHash)
                val debug = if (filter.size > 1)
                  extraDotGraph(x, mainHash, otherHash)
                else ""

                val extraGraphShow = extraGraph.map(x => (RefInfo.getShortInfo(x._1), x._2))
                val extraLongShow = extraGraph.map(x => (RefInfo.getLongInfo(x._1), x._2))

                val sizes = extraGraphShow.map(_._2)
                val sum = sizes.sum
                val max = sizes.max
                val len = sizes.size

                val list = List[String](meta._1, meta._2.toString, RefInfo.getLongInfo(x), extraLongShow.mkString(", "), extraGraphShow.mkString(", "), len.toString, sum.toString, max.toString, debug).map(_.replace("\t", ""))


                Some(list.mkString("\t"))
              } else {
                None
              }
            } else {
              None
            }

          case _ => None
        }

      }.getOrElse {
        FileUtils.appendLine("errors.log", x.toString);
        None
      }
    }.toVector
    FileUtils.write(s"cyber${y}.csv", res.iterator)
  }
